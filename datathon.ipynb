# %% [markdown]
# <a href="https://colab.research.google.com/github/jumanewton/KU-Datathon/blob/main/datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction

# %%
#importing importatnt libraries
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
#

# %%
df1=pd.read_csv('Global Superstore.csv',encoding='Latin1')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
### exploring Global Superstore.csv dataset
df1.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    5/2/2013    7/2/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320   5/11/2013   6/11/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# ## Customer Analysis

# %% [markdown]
# ### Introduction

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
# The dataset above, Global Superstore.csv, has 24 columns and 51290 rows
# the dataset has 3 data types, text objects(17 columns), two integer columns and five float data types columns
# we have missing values from the postal code column

# %%
df1.tail()
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398  US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470  US-2013-155768   2/12/2013   2/12/2013        Same Day
# 51288    9596  MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147  MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### frequency of purchase

# %%
#1 checking the frequency of purchase by each customer
customers=df1['Customer ID'].value_counts()
# Filter the DataFrame based on the counts
#customers_df = df1[df1['Customer ID'].isin(customers.index)]
# print(customers)
customers.head(10)
#the output of this code tells us that some customers have been consistent in buying items items from the store
# example is customer with ID PO-18850 who has visited and bought from the store 97 times
# Out:
# PO-18850    97
# BE-11335    94
# JG-15805    90
# SW-20755    89
# EM-13960    85
# MY-18295    85
# MP-17965    84
# ZC-21910    84
# CK-12205    83
# BW-11110    81
# Name: Customer ID, dtype: int64

# %% [markdown]
# ### frequent customers are contributing more revenue

# %%
#2.  Do the high frequent customers are contributing more revenue
# Group the data by customer ID and sum the sales for each customer
customer_sales = df1.groupby('Customer ID')['Sales'].sum()
customer_sales.head()
# Out:
# Customer ID
# AA-10315    13747.41300
# AA-10375     5884.19500
# AA-10480    17695.58978
# AA-10645    15343.89070
# AA-315       2243.25600
# Name: Sales, dtype: float64

# %%
expenditure_by_customer = df1.groupby('Customer ID')['Sales'].sum()

frequency_by_customer = df1.groupby('Customer ID').size()

# %%
print(expenditure_by_customer)
# Out:
# Customer ID
# AA-10315    13747.41300
# AA-10375     5884.19500
# AA-10480    17695.58978
# AA-10645    15343.89070
# AA-315       2243.25600
#                ...
# YS-21880    18703.60600
# ZC-11910        7.17300
# ZC-21910    28472.81926
# ZD-11925     2951.22600
# ZD-21925     9479.34440
# Name: Sales, Length: 1590, dtype: float64

# %%
print(frequency_by_customer)
# Out:
# Customer ID
# AA-10315    42
# AA-10375    42
# AA-10480    38
# AA-10645    73
# AA-315       8
#             ..
# YS-21880    54
# ZC-11910     1
# ZC-21910    84
# ZD-11925    18
# ZD-21925    36
# Length: 1590, dtype: int64

# %%
# sns.set_theme()
# plt.scatter(frequency_by_customer,expenditure_by_customer)
# correlation='positive'

# %%
sns.set_theme()
sns.relplot(x=frequency_by_customer,y=expenditure_by_customer)
plt.xlabel("Frequency")
correlation='positive'
plt.show()

# %%
# The data above, shows that customer frequency contributed to high revenue.
# from the graph, it shows that from an average frequency of 40 and above, the revenues were

# %% [markdown]
# ### profit Margin across the buckets

# %%
#3 Getting the profit Margin across the buckets.
# df1['Category'].value_counts()
profits=df1.groupby(['Sub-Category'])['Profit'].sum()
print(profits)
# Out:
# Sub-Category
# Accessories    129626.30620
# Appliances     141680.58940
# Art             57953.91090
# Binders         72449.84600
# Bookcases      161924.41950
# Chairs         140396.26750
# Copiers        258567.54818
# Envelopes       29601.11630
# Fasteners       11525.42410
# Furnishings     46967.42550
# Labels          15010.51200
# Machines        58867.87300
# Paper           59207.68270
# Phones         216717.00580
# Storage        108461.48980
# Supplies        22583.26310
# Tables         -64083.38870
# Name: Profit, dtype: float64

# %% [markdown]
# ### Most profitable customer segment

# %%
#4 Most profitable customer segment
M_seg=df1.groupby('Segment')['Profit'].sum()
print(M_seg)
# The most profitable customer segment turns to be the Consumer segement
# Out:
# Segment
# Consumer       749239.78206
# Corporate      441208.32866
# Home Office    277009.18056
# Name: Profit, dtype: float64

# %% [markdown]
# ### Customer Distribution across the country

# %%
#5 Customer Distribution across the country
country=df1['Country'].value_counts()
print(country)
# Out:
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Bahrain             2
# South Sudan         2
# Chad                2
# Burundi             2
# Eritrea             2
# Name: Country, Length: 147, dtype: int64

# %% [markdown]
# ## Product Analysis

# %% [markdown]
# ### The countries with their highest sales

# %%
#1 The countries with their highest sales
country_sales=df1.groupby(['Country'])['Sales'].sum()
print(country_sales)
# Out:
# Country
# Afghanistan    21673.32000
# Albania         3888.12000
# Algeria        36091.59000
# Angola         25554.00000
# Argentina      57511.78328
#                   ...
# Venezuela      26587.82956
# Vietnam        65800.19940
# Yemen           2465.71200
# Zambia         26035.50000
# Zimbabwe        3765.10500
# Name: Sales, Length: 147, dtype: float64

# %% [markdown]
# ### Top five profit making products on a yearly basis

# %%
#2 Top five profit making products on a yearly basis
# converting the date to a datetime module
df1['Order Date']=pd.to_datetime(df1['Order Date'])
# Out:
# <ipython-input-84-bef339da5727>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1['Order Date']=pd.to_datetime(df1['Order Date'])

# %%
df1['Order Date'].head(10)
# Out:
# 0   2012-07-31
# 1   2013-05-02
# 2   2013-10-17
# 3   2013-01-28
# 4   2013-05-11
# 5   2013-06-28
# 6   2011-07-11
# 7   2012-04-14
# 8   2014-10-14
# 9   2012-01-28
# Name: Order Date, dtype: datetime64[ns]

# %%
df1['Year'] = df1['Order Date'].dt.year
top_profit_products = grouped_data.groupby('Year').apply(lambda x: x.nlargest(5, 'Profit')).reset_index(drop=True)

# Group the data by year and product, and calculate profit
grouped_data = df1.groupby(['Year', 'Sub-Category'])['Profit'].sum().reset_index()

# Find the top profit product for each year
for year, data in top_profit_products.groupby('Year'):
    print(f"Year: {year}\n{'-'*20}")  # Print the year with a line separator
    print(data)  # Print the top profit products for the year
    print()  # Print an empty line for separation
# Out:
# Year: 2011
# --------------------
#    Year Sub-Category       Profit
# 0  2011       Phones  53927.48950
# 1  2011      Copiers  30375.09344
# 2  2011       Chairs  29943.15710
# 3  2011    Bookcases  27518.85750
# 4  2011   Appliances  22838.44130
#
# Year: 2012
# --------------------
#    Year Sub-Category      Profit
# 5  2012      Copiers  51843.2276
# 6  2012       Phones  45223.0498
# 7  2012  Accessories  33507.1002
# 8  2012       Chairs  28755.3467
# 9  2012    Bookcases  28137.2671
#
# Year: 2013
# --------------------
#     Year Sub-Category       Profit
# 10  2013      Copiers  72300.69118
# 11  2013       Phones  46908.82520
# 12  2013    Bookcases  43049.24440
# 13  2013   Appliances  41485.51600
# 14  2013       Chairs  40449.49210
#
# Year: 2014
# --------------------
#     Year Sub-Category        Profit
# 15  2014      Copiers  104048.53596
# 16  2014       Phones   70657.64130
# 17  2014    Bookcases   63219.05050
# 18  2014   Appliances   53040.50050
# ...

# %% [markdown]
# ### product price varying with sales

# %%
#3  How is the product price varying with sales - Is there any increase in sales with the decrease in price at any level?
sale_price = df1['Sub-Category'].value_counts()
quantity = df1.groupby('Sub-Category')['Quantity'].sum()
#
# Calculate unit price
df1['Unit_Price'] = df1['Sales'] / df1['Quantity']

# Create scatter plot
plt.figure(figsize=(10, 6))
sns.set_theme()
plt.scatter(df1['Unit_Price'], df1['Sales'], color='skyblue', alpha=0.7, marker='o', edgecolor='black')
plt.title('Unit Price vs. Sales')
plt.xlabel('Unit Price')
plt.ylabel('Sales')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# The above graph indicates that most products with a small unit price are being sold more with an
# average of unit price 500 or less
# increase in sales is indicated by decrease in price

# %% [markdown]
# ### average delivery time

# %%
# 4.     What is the average delivery time across the countries?
# we first convert ship date to a datetime type
df1['Ship Date']=pd.to_datetime(df1['Ship Date'])
# Out:
# <ipython-input-93-0e42719a0d7f>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1['Ship Date']=pd.to_datetime(df1['Ship Date'])

# %%
#  delivery time:
time=df1['Ship Date']-df1['Order Date']
# average
avg_time = df1.groupby('Country').apply(lambda x: (x['Ship Date'] - x['Order Date']).mean())
print(avg_time)
# the printout indicates some inconsistencies in the data,
# such that it appears like some orders were delivered even before being ordered
# Out:
# Country
# Afghanistan      9 days 04:21:49.090909090
# Albania                   27 days 07:30:00
# Algeria        -6 days +08:04:53.877551021
# Angola         -1 days +06:05:54.098360656
# Argentina       10 days 13:58:09.230769230
#                           ...
# Venezuela     -12 days +11:00:37.113402062
# Vietnam          3 days 06:36:40.754716981
# Yemen                     28 days 17:36:00
# Zambia         -5 days +13:52:56.470588236
# Zimbabwe                -51 days +18:54:00
# Length: 147, dtype: timedelta64[ns]

# %% [markdown]
# ### profit by month

# %%
# 5.    What is the profit by month? (Use a line chart to visualize this.)
df1['month'] = df1['Order Date'].dt.month #creating a new column to store the month value
profit_month = df1.groupby('month')['Profit'].sum()#getting the sum per month
# ploting a line chart
profit_month.plot()
plt.ylabel("Total Profit")
plt.show()
# the plot shows that festive seasons like december recorded the most sales in the dataset
# while july, a cold month had the least

# %% [markdown]
# ### Profit by category? By Subcategory?

# %%
#6.    Profit by category? By Subcategory?
# Grouping by category and sub-category, then calculating the sum of profits
profit_by_category = df1.groupby('Category')['Profit'].sum()
profit_by_subcategory = df1.groupby('Sub-Category')['Profit'].sum()

# Plotting
plt.figure(figsize=(12, 6))

# Horizontal bar chart for profit by category
plt.subplot(1, 2, 1)
profit_by_category.plot(kind='bar', color='skyblue')
plt.title('Profit by Category')
plt.xlabel('Profit')
plt.ylabel('Category')
plt.xticks(rotation=45, ha='right')

# Horizontal bar chart for profit by sub-category
plt.subplot(1, 2, 2)
profit_by_subcategory.plot(kind='barh', color='lightgreen')
plt.title('Profit by Sub-Category')
plt.xlabel('Profit')
plt.ylabel('Sub-Category')

plt.tight_layout()
plt.show()
# the graphs show that Table Sub category recorded the minimumu profit(loss)
# and copiers sub category recorded the maximum profit
# for the Categories columns, technology recorded the highest while furniture recorded the least

# %% [markdown]
# ### Profit by category and By Subcategory

# %%
#7.    Sales by month? By category? By subcategory?

# the sales by month:
salesby_month = df1.groupby('month')['Sales'].sum()
#print(salesby_month)

# Plotting line chart
plt.figure(figsize=(8, 6))
salesby_month.plot(kind='line', marker='o', color='skyblue')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)  # Add grid lines
plt.tight_layout()
plt.show()

# %%
# calculating the one for the Category column
profit_by_category = df1.groupby('Category')['Profit'].sum()
profit_by_subcategory = df1.groupby('Sub-Category')['Profit'].sum()

# Plotting bar chart for profit by category
plt.figure(figsize=(10, 6))
profit_by_category.plot(kind='bar', color='skyblue')
plt.title('Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines only on y-axis
plt.tight_layout()
plt.show()

# %%
# for the sub-category column
plt.figure(figsize=(10, 8))
profit_by_subcategory.plot(kind='barh', color='lightgreen')
plt.title('Profit by Sub-Category')
plt.xlabel('Profit')
plt.ylabel('Sub-Category')
plt.grid(axis='x')  # Add grid lines only on x-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# # The end
